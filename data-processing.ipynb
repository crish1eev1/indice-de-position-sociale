# %% [markdown]
# This notebook is dedicated to data collection, cleaning and creation of work files for the study of the public/private distribution of French schools

# %% [markdown]
# ### 1. Importing librairies

# %%
import time
startTime = time.time()

import pandas as pd
import os
import requests

# %% [markdown]
# ### 2. Creating the relevant folders and paths

# %%
# Defining current folder as our main directory
dirname = os.getcwd()

# location folders variables
data_in = dirname + "\\da_data_raw\\"
data_out = dirname + "\\da_data_workfiles\\"
graph_out = dirname + "\\graphs\\"

# Checking if data_in path is not present, then create it
if not os.path.exists(data_in):
    os.makedirs(data_in)
    print(f"Directory Created: {data_in}")
else: 
    print(f"Already existing directory: {data_in}")
    
# Checking if data_out path is not present then create it
if not os.path.exists(data_out):
    os.makedirs(data_out)
    print(f"Directory Created: {data_out}")
else:
    print(f"Already existing directory: {data_out}")
    
# Checking if data_out path is not present then create it
if not os.path.exists(graph_out):
    os.makedirs(graph_out)
    print(f"Directory Created: {graph_out}")
else:
    print(f"Already existing directory: {graph_out}")    

# Printing main directories we will work with
print(f"\nMain directory: {dirname}")
print(f"Raw data folder: {data_in}")
print(f"Workfile folder: {data_out}")
# Out:
# Already existing directory: c:\Users\33671\Documents\Python\IPS\da_data_raw\
# Already existing directory: c:\Users\33671\Documents\Python\IPS\da_data_workfiles\
# Already existing directory: c:\Users\33671\Documents\Python\IPS\graphs\
#
# Main directory: c:\Users\33671\Documents\Python\IPS
# Raw data folder: c:\Users\33671\Documents\Python\IPS\da_data_raw\
# Workfile folder: c:\Users\33671\Documents\Python\IPS\da_data_workfiles\

# %% [markdown]
# Temporary code (to comment later)

# %%
# Getting current date
datestr = time.strftime("%Y-%m-%d")

# location folders variables (temporary - to comment later)
data_in_temporary = dirname + "\\da_data_raw\\" + datestr + "\\"
data_out_temporary = dirname + "\\da_data_workfiles\\" + datestr + "\\"

# Checking if data_in path is not present, then create it
if not os.path.exists(data_in_temporary):
    os.makedirs(data_in_temporary)
    print(f"Directory Created: {data_in_temporary}")
else: 
    print(f"Already existing directory: {data_in_temporary}")
    
# Checking if data_out path is not present then create it
if not os.path.exists(data_out_temporary):
    os.makedirs(data_out_temporary)
    print(f"Directory Created: {data_out_temporary}")
else:
    print(f"Already existing directory: {data_out_temporary}")

# Printing main directories we will work with
print(f"\nMain directory: {dirname}")
print(f"Raw data folder: {data_in_temporary}")
print(f"Workfile folder: {data_out_temporary}")
# Out:
# Directory Created: c:\Users\33671\Documents\Python\IPS\da_data_raw\2022-11-12\
# Directory Created: c:\Users\33671\Documents\Python\IPS\da_data_workfiles\2022-11-12\
#
# Main directory: c:\Users\33671\Documents\Python\IPS
# Raw data folder: c:\Users\33671\Documents\Python\IPS\da_data_raw\2022-11-12\
# Workfile folder: c:\Users\33671\Documents\Python\IPS\da_data_workfiles\2022-11-12\

# %% [markdown]
# ### 3. Verifying APIs responses

# %%
#fr-en-ips_colleges
dataset_id = "fr-en-ips_colleges"
format = "json"
limit = "10"
r = requests.get(f"https://data.education.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}", 
                 timeout=2)
print(f"{dataset_id}")
print(f"URL: {r.url}")
print(f"HTTP Response Status Code: {r.status_code}") 
print(f"HTTP Error: {r.raise_for_status()}")
print(f"Encoding: {r.encoding}\n")
r.close()

#fr-en-ips_ecoles
dataset_id = "fr-en-ips_ecoles"
format = "json"
limit = "10"
r = requests.get(f"https://data.education.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}", 
                 timeout=2)
print(f"{dataset_id}")
print(f"URL: {r.url}")
print(f"HTTP Response Status Code: {r.status_code}") 
print(f"HTTP Error: {r.raise_for_status()}")
print(f"Encoding: {r.encoding}\n")
r.close()

#fr-en-dnb-par-etablissement
dataset_id = "fr-en-dnb-par-etablissement"
format = "json"
limit = "10"
r = requests.get(f"https://data.education.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}", 
                 timeout=2)
print(f"{dataset_id}")
print(f"URL: {r.url}")
print(f"HTTP Response Status Code: {r.status_code}") 
print(f"HTTP Error: {r.raise_for_status()}")
print(f"Encoding: {r.encoding}\n")
r.close()

#fr-en-adresse-et-geolocalisation-etablissements-premier-et-second-degre
dataset_id = "fr-en-adresse-et-geolocalisation-etablissements-premier-et-second-degre"
format = "json"
limit = "10"
r = requests.get(f"https://data.education.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}", 
                 timeout=2)
print(f"{dataset_id}")
print(f"URL: {r.url}")
print(f"HTTP Response Status Code: {r.status_code}") 
print(f"HTTP Error: {r.raise_for_status()}")
print(f"Encoding: {r.encoding}\n")
r.close()

#georef-france-commune
# dataset_id = "georef-france-commune"
# format = "json"
# limit = "10"
# r = requests.get(f"https://public.opendatasoft.com/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}", 
#                  timeout=2)
# print(f"{dataset_id}")
# print(f"URL: {r.url}")
# print(f"HTTP Response Status Code: {r.status_code}") 
# print(f"HTTP Error: {r.raise_for_status()}")
# print(f"Encoding: {r.encoding}\n")
# r.close()
# Out:
# fr-en-ips_colleges
# URL: https://data.education.gouv.fr/api/v2/catalog/datasets/fr-en-ips_colleges/exports/json?limit=10
# HTTP Response Status Code: 200
# HTTP Error: None
# Encoding: utf-8
#
# fr-en-ips_ecoles
# URL: https://data.education.gouv.fr/api/v2/catalog/datasets/fr-en-ips_ecoles/exports/json?limit=10
# HTTP Response Status Code: 200
# HTTP Error: None
# Encoding: utf-8
#
# fr-en-dnb-par-etablissement
# URL: https://data.education.gouv.fr/api/v2/catalog/datasets/fr-en-dnb-par-etablissement/exports/json?limit=10
# HTTP Response Status Code: 200
# HTTP Error: None
# Encoding: utf-8
#
# fr-en-adresse-et-geolocalisation-etablissements-premier-et-second-degre
# URL: https://data.education.gouv.fr/api/v2/catalog/datasets/fr-en-adresse-et-geolocalisation-etablissements-premier-et-second-degre/exports/json?limit=10
# HTTP Response Status Code: 200
# HTTP Error: None
# Encoding: utf-8

# %% [markdown]
# ### 4. Data Collection

# %% [markdown]
# ##### ips_colleges dataset

# %%
# Loading data
dataset_id = "fr-en-ips_colleges"
format = "json"
limit = "-1" # argument to pass to get the full dataset 
df_raw_ips_colleges = pd.read_json(f"https://data.education.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}")

# Adding column about the type of school
df_raw_ips_colleges['type_etablissement']="COLLEGE"

# %%
df_raw_ips_colleges.sample(5)
# Out:
#      rentree_scolaire          academie code_du_departement       departement  \
# 1584        2021-2022     ORLEANS-TOURS                 018              CHER
# 6359        2021-2022  CLERMONT-FERRAND                 063       PUY-DE-DOME
# 1709        2021-2022          TOULOUSE                 031     HAUTE-GARONNE
# 1004        2021-2022             PARIS                 075             PARIS
# 3210        2021-2022            NANTES                 044  LOIRE-ATLANTIQUE
#
#            uai   nom_de_l_etablissment code_insee_de_la_commune  \
# 1584  0180710Z  COLLEGE CLAUDE DEBUSSY                    18108
# 6359  0631411S   COLLEGE BLAISE PASCAL                    63113
# 1709  0310031R  COLLEGE FRANCOIS CAZES                    31471
# 1004  0754706H     COLLEGE MARIE CURIE                    75118
# 3210  0442835T     COLLEGE SIMONE VEIL                    44109
#
#              nom_de_la_commune secteur    ips type_etablissement
# 1584   LA GUERCHE SUR L AUBOIS  public   92.3            COLLEGE
# 6359          CLERMONT FERRAND  public  101.9            COLLEGE
# 1709            SAINT BEAT LEZ  public  109.1            COLLEGE
# 1004  PARIS 18E ARRONDISSEMENT  public  103.9            COLLEGE
# 3210                    NANTES  public  106.4            COLLEGE

# %% [markdown]
# ##### ips_ecoles dataset

# %%
# Loading data
dataset_id = "fr-en-ips_ecoles"
format = "json"
limit = "-1" # argument to pass to get the full dataset 
df_raw_ips_ecoles = pd.read_json(f"https://data.education.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}")

# Adding column about the type of school
df_raw_ips_ecoles['type_etablissement']="ECOLE"

# %%
df_raw_ips_ecoles.sample(5)
# Out:
#       rentree_scolaire       academie code_du_departement      departement  \
# 20584        2021-2022       TOULOUSE                 081             TARN
# 31364        2021-2022     NANCY-METZ                 088           VOSGES
# 31155        2021-2022  AIX-MARSEILLE                 084         VAUCLUSE
# 20648        2021-2022       TOULOUSE                 082  TARN-ET-GARONNE
# 3253         2021-2022       BESANCON                 025            DOUBS
#
#             uai              nom_de_l_etablissment code_insee_de_la_commune  \
# 20584  0810360B                     ECOLE PRIMAIRE                    81285
# 31364  0881648N           ECOLE PRIMAIRE DU CENTRE                    88481
# 31155  0840656G        ECOLE PRIMAIRE GABRIEL PERI                    84019
# 20648  0820810K  ECOLE ELEMENTAIRE PIERRE BONHOURE                    82124
# 3253   0251692D           ECOLE ELEMENTAIRE CENTRE                    25321
#
#       nom_de_la_commune secteur    ips type_etablissement
# 20584           SERENAC  public   83.9              ECOLE
# 31364          URIMENIL  public  109.4              ECOLE
# 31155           BOLLENE  public   81.2              ECOLE
# 20648         MONTBETON  public  105.4              ECOLE
# 3253     VILLERS LE LAC  public  101.3              ECOLE

# %% [markdown]
# ##### dnb-par-etablissement dataset

# %%
dataset_id = "fr-en-dnb-par-etablissement"
format = "json"
limit = "-1" # argument to pass to get the full dataset 
df_raw_dnb_par_etablissement = pd.read_json(f"https://data.education.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}")

# %%
df_raw_dnb_par_etablissement.sample(5)
# Out:
#         session numero_d_etablissement denomination_principale  \
# 14041      2019               0840066R                 COLLEGE
# 27853      2009               0400012W                 COLLEGE
# 88590      2009               0911491B                 COLLEGE
# 56879      2006               0511216V                 COLLEGE
# 114948     2017               0640168K                 COLLEGE
#
#                         patronyme secteur_d_enseignement  \
# 14041   NOTRE DAME DU BON ACCUEIL                  PRIVE
# 27853                 VAL D ADOUR                 PUBLIC
# 88590                   CONDORCET                 PUBLIC
# 56879                 JEAN MOULIN                 PUBLIC
# 114948                 ETCHECOPAR                  PRIVE
#
#        commune_et_arrondissement commune_et_arrondissement_lib_l departement  \
# 14041                      84080                         MONTEUX         084
# 27853                      40117             GRENADE-SUR-L'ADOUR         040
# 88590                      91200                         DOURDAN         091
# 56879                      51506                    SAINT-MEMMIE         051
# 114948                     64493                    SAINT-PALAIS         064
#
#          departement_libelle  academie  ... region  \
# 14041               VAUCLUSE         2  ...     18
# 27853                 LANDES         4  ...     15
# 88590                ESSONNE        25  ...     10
# 56879                  MARNE        19  ...      6
# 114948  PYRENEES-ATLANTIQUES         4  ...     15
#
#                     region_libelle nombre_d_inscrits  nombre_de_presents  \
# 14041   PROVENCE-ALPES-COTE D'AZUR               121                 120
# 27853           NOUVELLE-AQUITAINE                80                  80
# 88590                ILE-DE-FRANCE               186                 183
# 56879                    GRAND EST               108                 106
# 114948          NOUVELLE-AQUITAINE                45                  45
#
#         nombre_total_d_admis  nombre_d_admis_sans_mention  \
# 14041                    118                           22
# 27853                     74                           25
# 88590                    158                           71
# 56879                     77                           42
# 114948                    40                            1
#
#         nombre_d_admis_mention_ab  nombre_d_admis_mention_b  \
# 14041                          40                        35
# 27853                          30                        15
# 88590                          49                        25
# 56879                          20                        11
# 114948                         13                        13
#
#         nombre_d_admis_mention_tb  taux_de_reussite
# 14041                          21            98,30%
# 27853                           4            92,50%
# 88590                          13            86,30%
# 56879                           4            72,60%
# 114948                         13            88,80%
#
# [5 rows x 21 columns]

# %%
# Check school type distribution based on last avaiable year results
df_raw_dnb_par_etablissement[df_raw_dnb_par_etablissement['session'] == 2021]['denomination_principale'].value_counts()
# Out:
# COLLEGE                6942
# LYCEE PROFESSIONNEL    1315
# LYCEE                   481
# EREA                     58
# AUTRE                    17
# CFA                       3
# Name: denomination_principale, dtype: int64

# %% [markdown]
# ##### fr-en-adresse-et-geolocalisation-etablissements-premier-et-second-degre dataset

# %%
# Loading data
dataset_id = "fr-en-adresse-et-geolocalisation-etablissements-premier-et-second-degre"
format = "json"
limit = "-1" # argument to pass to get the full dataset 
df_raw_geolocalisation = pd.read_json(f"https://data.education.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}")

# %%
df_raw_geolocalisation.sample(5)
# Out:
#       numero_uai                  appellation_officielle  \
# 46836   0750663N  Lycée général et technologique Chaptal
# 41444   0440748Z       Ecole primaire publique Astrolabe
# 27303   0630924M                          Ecole primaire
# 63741   0851353J          Ecole primaire publique LA MER
# 13057   0631587H         Ecole maternelle Philippe Arbos
#
#               denomination_principale   patronyme_uai  \
# 46836  LYCEE GENERAL ET TECHNOLOGIQUE         CHAPTAL
# 41444         ECOLE PRIMAIRE PUBLIQUE       ASTROLABE
# 27303                  ECOLE PRIMAIRE            None
# 63741        ECOLE PRIMAIRE  PUBLIQUE          LA MER
# 13057       ECOLE MATERNELLE PUBLIQUE  PHILIPPE ARBOS
#
#       secteur_public_prive_libe                   adresse_uai lieu_dit_uai  \
# 46836                    Public  45 boulevard des Batignolles         None
# 41444                    Public         3 rue Prosper Mérimée         None
# 27303                    Public       Rue marechal de turenne         None
# 63741                    Public         50 avenue de la Plage         None
# 13057                    Public   Rue des Hauts de Chanturgue         None
#
#       boite_postale_uai  code_postal_uai localite_acheminement_uai  ...  \
# 46836              None            75008                     PARIS  ...
# 41444              None            44330                 LE PALLET  ...
# 27303              None            63350                      JOZE  ...
# 63741              None            85360        LA TRANCHE SUR MER  ...
# 13057              None            63100          CLERMONT FERRAND  ...
#
#       code_commune  libelle_departement        libelle_region  \
# 46836        75108                Paris         Ile-de-France
# 41444        44117     Loire-Atlantique      Pays de la Loire
# 27303        63180          Puy-de-Dôme  Auvergne-Rhône-Alpes
# 63741        85294               Vendée      Pays de la Loire
# 13057        63113          Puy-de-Dôme  Auvergne-Rhône-Alpes
#
#        libelle_academie                                           position  \
# 46836             Paris  {'lon': 2.319669465196226, 'lat': 48.881734614...
# 41444            Nantes  {'lon': -1.336939440396343, 'lat': 47.14018417...
# 27303  Clermont-Ferrand  {'lon': 3.301650282544672, 'lat': 45.863866656...
# 63741            Nantes  {'lon': -1.438599619043155, 'lat': 46.34101801...
# 13057  Clermont-Ferrand  {'lon': 3.10156948642659, 'lat': 45.8121021731...
#
#        secteur_prive_code_type_contrat secteur_prive_libelle_type_contrat  \
# 46836                             99.0                         SANS OBJET
# 41444                             99.0                         SANS OBJET
# 27303                             99.0                         SANS OBJET
# 63741                             99.0                         SANS OBJET
# 13057                             99.0                         SANS OBJET
#
#       code_ministere                   libelle_ministere date_ouverture
# 46836              6  MINISTERE DE L'EDUCATION NATIONALE     1965-05-01
# 41444              6  MINISTERE DE L'EDUCATION NATIONALE     1970-01-21
# 27303              6  MINISTERE DE L'EDUCATION NATIONALE     1966-08-08
# 63741              6  MINISTERE DE L'EDUCATION NATIONALE     1983-09-01
# 13057              6  MINISTERE DE L'EDUCATION NATIONALE     1977-05-23
#
# [5 rows x 35 columns]

# %% [markdown]
# ##### georef-france-commune

# %%
# dataset_id = "georef-france-commune"
# format = "json"
# limit = "-1" # argument to pass to get the full dataset 
# columns = "bv2012_code" + "%2C" + "bv2012_name" + "%2C" + "com_uu2020_status" 
# df_raw_georef = pd.read_json(f"https://public.opendatasoft.com/api/v2/catalog/datasets/{dataset_id}/exports/{format}?limit={limit}&select={columns}")

# %% [markdown]
# ##### typo-rur

# %%
df_raw_typo_rur = pd.read_csv('./da_data_raw/typo-rur.csv')
df_raw_typo_rur
# Out:
#       codgeo                   libgeo zonage_rur
# 0      01001  L'Abergement-Clémenciat        tr2
# 1      01002    L'Abergement-de-Varey        tr1
# 2      01004        Ambérieu-en-Bugey        tr5
# 3      01005      Ambérieux-en-Dombes        tr3
# 4      01006                  Ambléon        tr1
# ...      ...                      ...        ...
# 34960  97613            M'Tsangamouji        tr5
# 34961  97614                 Ouangani        tr5
# 34962  97615                 Pamandzi        tr5
# 34963  97616                     Sada        tr5
# 34964  97617                 Tsingoni        tr5
#
# [34965 rows x 3 columns]

# %%
df_raw_typo_rur['zonage_rur'].value_counts()
# Out:
# tr1    8108
# tr2    8096
# tr3    7394
# tr4    7174
# tr5    3419
# tr6     774
# Name: zonage_rur, dtype: int64

# %%
df_raw_typo_rur['zonage_rur_lib'] = df_raw_typo_rur['zonage_rur'].map({'tr1':'rural autonome très peu dense', 
                                                                       'tr2': 'rural autonome peu dense', 
                                                                       'tr3': 'rural sous faible influence d\'un pole', 
                                                                       'tr4': 'rural sous forte influence d\'un pole',
                                                                       'tr5': 'urbain densité intermédiaire',
                                                                       'tr6': 'urbain dense'
                                                                       }
                                                                      )

# %%
df_raw_typo_rur['zonage_rur_lib'] = df_raw_typo_rur['zonage_rur'].map({'tr1':'rural autonome très peu dense', 
                                                                       'tr2': 'rural autonome peu dense', 
                                                                       'tr3': 'rural sous faible influence d\'un pole', 
                                                                       'tr4': 'rural sous forte influence d\'un pole',
                                                                       'tr5': 'urbain densité intermédiaire',
                                                                       'tr6': 'urbain dense'
                                                                       }
                                                                      )

# %%
df_raw_typo_rur['zonage_rur'] = df_raw_typo_rur['zonage_rur'].map({'tr1': 1, 
                                                                       'tr2': 2, 
                                                                       'tr3': 3, 
                                                                       'tr4': 4,
                                                                       'tr5': 5,
                                                                       'tr6': 6
                                                                       }
                                                                      )

# %%
df_raw_typo_rur.head()
# Out:
#   codgeo                   libgeo  zonage_rur  \
# 0  01001  L'Abergement-Clémenciat           2
# 1  01002    L'Abergement-de-Varey           1
# 2  01004        Ambérieu-en-Bugey           5
# 3  01005      Ambérieux-en-Dombes           3
# 4  01006                  Ambléon           1
#
#                           zonage_rur_lib
# 0               rural autonome peu dense
# 1          rural autonome très peu dense
# 2           urbain densité intermédiaire
# 3  rural sous faible influence d'un pole
# 4          rural autonome très peu dense

# %%
df_raw_typo_rur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34965 entries, 0 to 34964
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   codgeo          34965 non-null  object
#  1   libgeo          34965 non-null  object
#  2   zonage_rur      34965 non-null  int64
#  3   zonage_rur_lib  34965 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ##### Niveau_de_vie_2013_a_la_commune dataset

# %%
# Loading data
df_raw_revenus_par_commune = pd.read_excel("https://www.data.gouv.fr/fr/datasets/r/d3ce0107-416f-42cf-a335-d71f89b00b21")

# %% [markdown]
# ### 5. Exporting raw data to CSV

# %%
# Raw datasets export
file_name = "ips-colleges" + ".csv"
print(f"file name: {file_name}")
df_raw_ips_colleges.to_csv(data_in + file_name, index = False)

file_name = "ips-ecoles" + ".csv"
print(f"file name: {file_name}")
df_raw_ips_ecoles.to_csv(data_in + file_name, index = False)

file_name = "dnb-par-etablissement" + ".csv"
print(f"file name: {file_name}")
df_raw_dnb_par_etablissement.to_csv(data_in + file_name, index = False)

file_name = "geolocalisation-etablissement" + ".csv"
print(f"file name: {file_name}")
df_raw_geolocalisation.to_csv(data_in + file_name, index = False)

file_name = "revenus-par-commune" + ".csv"
print(f"file name: {file_name}")
df_raw_revenus_par_commune.to_csv(data_in + file_name, index = False)

# file_name = "georef-par-commune" + ".csv"
# print(f"file name: {file_name}")
# df_raw_georef.to_csv(data_in + file_name, index = False)
# Out:
# file name: ips-colleges.csv
# file name: ips-ecoles.csv
# file name: dnb-par-etablissement.csv
# file name: geolocalisation-etablissement.csv
# file name: revenus-par-commune.csv

# %% [markdown]
# #### Exporting raw data to CSV (temporary code - to comment later)

# %%
# timestr = time.strftime("%Y-%m-%d_%H-%M-%S")
# file_name = "ips-colleges_" + timestr + ".csv"
# print(f"file name: {file_name}")
# df_raw_ips_colleges.to_csv(data_in_temporary + file_name, index = False)


# timestr = time.strftime("%Y-%m-%d_%H-%M-%S")
# file_name = "ips-ecoles_" + timestr + ".csv"
# print(f"file name: {file_name}")
# df_raw_ips_ecoles.to_csv(data_in_temporary + file_name, index = False)

# timestr = time.strftime("%Y-%m-%d_%H-%M-%S")
# file_name = "dnb-par-etablissement_" + timestr + ".csv"
# print(f"file name: {file_name}")
# df_raw_dnb_par_etablissement.to_csv(data_in_temporary + file_name, index = False)

# timestr = time.strftime("%Y-%m-%d_%H-%M-%S")
# file_name = "geolocalisation-etablissement_" + timestr + ".csv"
# print(f"file name: {file_name}")
# df_raw_geolocalisation.to_csv(data_in_temporary + file_name, index = False)

# timestr = time.strftime("%Y-%m-%d_%H-%M-%S")
# file_name = "revenus-par-commune_" + timestr + ".csv"
# print(f"file name: {file_name}")
# df_raw_revenus_par_commune.to_csv(data_in_temporary + file_name, index = False)

# %% [markdown]
# ### 6. Merging data into master file

# %% [markdown]
# ##### ips_ecoles & ips_colleges dataframes

# %%
# Adding columns about the type of school
df_raw_ips_colleges['type_etablissement']="COLLEGE"
df_raw_ips_ecoles['type_etablissement']="ECOLE"

# %%
df_master = pd.concat([df_raw_ips_colleges, df_raw_ips_ecoles])

# %%
#safety check
print(f"df_raw_ips_colleges N = {len(df_raw_ips_colleges)}")
print(f"df_raw_ips_ecoles N = {len(df_raw_ips_ecoles)}")
print(f"df_master N = {len(df_master)}")
print(len(df_raw_ips_colleges) + len(df_raw_ips_ecoles) == len(df_master))
print(f"unique uai = {df_master['uai'].nunique()}")
# Out:
# df_raw_ips_colleges N = 6967
# df_raw_ips_ecoles N = 32091
# df_master N = 39058
# True
# unique uai = 39058

# %% [markdown]
# ##### dnb_par_etablissement

# %% [markdown]
# College certificate success rate is calculated based on admissions devived by attendees (not registrants). We will keep this convention to calculate honors rates

# %%
df_raw_dnb_par_etablissement.sample(5)
# Out:
#        session numero_d_etablissement denomination_principale  \
# 8927      2011               0180568V                 COLLEGE
# 91246     2010               0672477D                     CFA
# 43781     2013               0820017Y                 COLLEGE
# 81613     2008               0931489N                 COLLEGE
# 36738     2007               0590157A                 COLLEGE
#
#                           patronyme secteur_d_enseignement  \
# 8927   ST JEAN BAPTISTE DE LA SALLE                  PRIVE
# 91246             RATTACHE AU LEGTA                 PUBLIC
# 43781           FRANCOIS MITTERRAND                 PUBLIC
# 81613         FEDERICO GARCIA LORCA                 PUBLIC
# 36738                 SAINT EXUPERY                 PUBLIC
#
#       commune_et_arrondissement commune_et_arrondissement_lib_l departement  \
# 8927                      18033                         BOURGES         018
# 91246                     67348                         OBERNAI         067
# 43781                     82112                         MOISSAC         082
# 81613                     93066                     SAINT-DENIS         093
# 36738                     59447                         ONNAING         059
#
#       departement_libelle  academie  ... region       region_libelle  \
# 8927                 CHER        18  ...      4  CENTRE-VAL DE LOIRE
# 91246            BAS-RHIN        15  ...      6            GRAND EST
# 43781     TARN-ET-GARONNE        16  ...     16            OCCITANIE
# 81613   SEINE-SAINT-DENIS        24  ...     10        ILE-DE-FRANCE
# 36738                NORD         9  ...      9      HAUTS-DE-FRANCE
#
#       nombre_d_inscrits  nombre_de_presents  nombre_total_d_admis  \
# 8927                 21                  21                    19
# 91246                17                  17                    15
# 43781               122                 119                   101
# 81613               118                 110                    79
# 36738               144                 134                    99
#
#        nombre_d_admis_sans_mention  nombre_d_admis_mention_ab  \
# 8927                             9                          5
# 91246                            7                          5
# 43781                           45                         21
# 81613                           47                         23
# 36738                           42                         28
#
#        nombre_d_admis_mention_b  nombre_d_admis_mention_tb  taux_de_reussite
# 8927                          5                          0            90,40%
# 91246                         3                          0            88,20%
# 43781                        24                         11            84,80%
# 81613                         7                          2            71,80%
# 36738                        24                          5            73,80%
#
# [5 rows x 21 columns]

# %%
# renaming key column
df_raw_dnb_par_etablissement = df_raw_dnb_par_etablissement.rename(columns = {'numero_d_etablissement': 'uai'})

# %%
#converting dnb string to float
df_raw_dnb_par_etablissement['taux_de_reussite'] = df_raw_dnb_par_etablissement['taux_de_reussite'].str.strip('%').str.replace(',', '.')
df_raw_dnb_par_etablissement['taux_de_reussite'] = df_raw_dnb_par_etablissement['taux_de_reussite'].astype('float')

# %%
df_raw_dnb_par_etablissement['dnb_taux_de_sans_mention'] = df_raw_dnb_par_etablissement['nombre_d_admis_sans_mention'] / df_raw_dnb_par_etablissement['nombre_de_presents']
df_raw_dnb_par_etablissement['dnb_taux_de_mention_ab'] = df_raw_dnb_par_etablissement['nombre_d_admis_mention_ab'] / df_raw_dnb_par_etablissement['nombre_de_presents']
df_raw_dnb_par_etablissement['dnb_taux_de_mention_b'] = df_raw_dnb_par_etablissement['nombre_d_admis_mention_b'] / df_raw_dnb_par_etablissement['nombre_de_presents']
df_raw_dnb_par_etablissement['dnb_taux_de_mention_tb'] = df_raw_dnb_par_etablissement['nombre_d_admis_mention_tb'] / df_raw_dnb_par_etablissement['nombre_de_presents']
df_raw_dnb_par_etablissement.sample(5)
# Out:
#        session       uai denomination_principale                patronyme  \
# 5848      2007  0022042J                   LYCEE               JEAN BOUIN
# 12441     2009  0760030V                   LYCEE        FERDINAND BUISSON
# 5953      2007  0130063Y     LYCEE PROFESSIONNEL                LEAU (BD)
# 48229     2014  0131931D                 COLLEGE                   THIERS
# 17824     2015  0150061K                 COLLEGE  NOTRE DAME DES MIRACLES
#
#       secteur_d_enseignement commune_et_arrondissement  \
# 5848                  PUBLIC                     02691
# 12441                 PUBLIC                     76231
# 5953                  PUBLIC                     13208
# 48229                 PUBLIC                     13201
# 17824                  PRIVE                     15120
#
#       commune_et_arrondissement_lib_l departement departement_libelle  \
# 5848                    SAINT-QUENTIN         002               AISNE
# 12441                          ELBEUF         076      SEINE MARITIME
# 5953     MARSEILLE 8E  ARRONDISSEMENT         013    BOUCHES-DU-RHONE
# 48229   MARSEILLE  1ER ARRONDISSEMENT         013    BOUCHES-DU-RHONE
# 17824                         MAURIAC         015              CANTAL
#
#        academie  ... nombre_total_d_admis  nombre_d_admis_sans_mention  \
# 5848         20  ...                   21                           17
# 12441        21  ...                   35                           28
# 5953          2  ...                   28                           22
# 48229         2  ...                   92                           22
# 17824         6  ...                   44                           15
#
#       nombre_d_admis_mention_ab  nombre_d_admis_mention_b  \
# 5848                          4                         0
# 12441                         5                         2
# 5953                          4                         2
# 48229                        29                        29
# 17824                        14                        10
#
#        nombre_d_admis_mention_tb  taux_de_reussite  dnb_taux_de_sans_mention  \
# 5848                           0             100.0                  0.809524
# 12441                          0              94.5                  0.756757
# 5953                           0              71.7                  0.564103
# 48229                         12              82.8                  0.198198
# 17824                          5             100.0                  0.340909
#
#        dnb_taux_de_mention_ab  dnb_taux_de_mention_b  dnb_taux_de_mention_tb
# 5848                 0.190476               0.000000                0.000000
# 12441                0.135135               0.054054                0.000000
# 5953                 0.102564               0.051282                0.000000
# 48229                0.261261               0.261261                0.108108
# 17824                0.318182               0.227273                0.113636
#
# [5 rows x 25 columns]

# %%
# Removing columns
df_raw_dnb_par_etablissement.drop(columns=['nombre_d_admis_sans_mention', 'nombre_d_admis_mention_ab', 'nombre_d_admis_mention_b', 'nombre_d_admis_mention_tb'], 
        errors='ignore', 
        inplace=True)
df_raw_dnb_par_etablissement.sample(5)
# Out:
#         session       uai denomination_principale     patronyme  \
# 88891      2006  0831116M                 COLLEGE     L'ESTEREL
# 121850     2021  0580038B                 COLLEGE   LES AMOGNES
# 90562      2010  0520822L                 COLLEGE       CRESSOT
# 95159      2006  0280869T                 COLLEGE   JEAN MONNET
# 84660      2011  0830956N                 COLLEGE  EMILE THOMAS
#
#        secteur_d_enseignement commune_et_arrondissement  \
# 88891                  PUBLIC                     83118
# 121850                 PUBLIC                     58232
# 90562                  PUBLIC                     52250
# 95159                  PUBLIC                     28214
# 84660                  PUBLIC                     83050
#
#        commune_et_arrondissement_lib_l departement departement_libelle  \
# 88891                    SAINT-RAPHAEL         083                 VAR
# 121850               SAINT-BENIN-D'AZY         058              NIEVRE
# 90562                        JOINVILLE         052         HAUTE-MARNE
# 95159                         LA LOUPE         028        EURE-ET-LOIR
# 84660                       DRAGUIGNAN         083                 VAR
#
#         academie  ... region              region_libelle nombre_d_inscrits  \
# 88891         23  ...     18  PROVENCE-ALPES-COTE D'AZUR               164
# 121850         7  ...      2     BOURGOGNE-FRANCHE-COMTE                47
# 90562         19  ...      6                   GRAND EST                84
# 95159         18  ...      4         CENTRE-VAL DE LOIRE                74
# 84660         23  ...     18  PROVENCE-ALPES-COTE D'AZUR               147
#
#         nombre_de_presents  nombre_total_d_admis  taux_de_reussite  \
# 88891                  161                   142              88.1
# 121850                  46                    41              89.1
# 90562                   81                    66              81.4
# 95159                   73                    50              68.4
# 84660                  139                   118              84.8
#
#         dnb_taux_de_sans_mention  dnb_taux_de_mention_ab  \
# 88891                   0.428571                0.267081
# 121850                  0.239130                0.173913
# 90562                   0.456790                0.197531
# 95159                   0.301370                0.232877
# 84660                   0.489209                0.158273
#
#         dnb_taux_de_mention_b  dnb_taux_de_mention_tb
# 88891                0.130435                0.055901
# 121850               0.152174                0.326087
# 90562                0.098765                0.061728
# 95159                0.109589                0.041096
# 84660                0.086331                0.115108
#
# [5 rows x 21 columns]

# %%
#creating sub-dataframe for college cerficate dataframe based on session year  
dfs_dnb_par_etablissement = {}
for session in df_raw_dnb_par_etablissement['session'].unique():
    dfs_dnb_par_etablissement[session] = pd.DataFrame(df_raw_dnb_par_etablissement[df_raw_dnb_par_etablissement['session'] == session])
    dfs_dnb_par_etablissement[session] = dfs_dnb_par_etablissement[session].rename(columns = 
                                                                                   {'nombre_d_inscrits': f'dnb_nombre_d_inscrits_{session}', 
                                                                                    'nombre_de_presents': f'dnb_nombre_de_presents_{session}',
                                                                                    'nombre_total_d_admis': f'dnb_nombre_de_presents_{session}',
                                                                                    'taux_de_reussite': f'dnb_taux_de_reussite_{session}',
                                                                                    'dnb_taux_de_sans_mention': f'dnb_taux_de_sans_mention_{session}',
                                                                                    'dnb_taux_de_mention_ab': f'dnb_taux_de_mention_ab_{session}',
                                                                                    'dnb_taux_de_mention_b': f'dnb_taux_de_mention_b_{session}',
                                                                                    'dnb_taux_de_mention_tb': f'dnb_taux_de_mention_tb_{session}',
                                                                                    })
    print(f"{session}: {len(dfs_dnb_par_etablissement[session])}")
# Out:
# 2007: 8623
# 2008: 8656
# 2011: 8696
# 2012: 8697
# 2006: 8562
# 2009: 8672
# 2010: 8646
# 2013: 8732
# 2014: 8746
# 2019: 8797
# 2020: 8807
# 2015: 8752
# 2017: 8796
# 2018: 8802
# 2016: 8780
# 2021: 8816

# %%
df_master.head()
# Out:
#   rentree_scolaire academie code_du_departement departement       uai  \
# 0        2021-2022     LYON                 001         AIN  0010025X
# 1        2021-2022     LYON                 001         AIN  0010041P
# 2        2021-2022     LYON                 001         AIN  0010092V
# 3        2021-2022     LYON                 001         AIN  0010896U
# 4        2021-2022     LYON                 001         AIN  0010938P
#
#         nom_de_l_etablissment code_insee_de_la_commune     nom_de_la_commune  \
# 0      COLLEGE PAUL SIXDENIER                    01185  PLATEAU D HAUTEVILLE
# 1            COLLEGE VAUGELAS                    01244             MEXIMIEUX
# 2  COLLEGE PRIVE SAINT JOSEPH                    01283               OYONNAX
# 3       COLLEGE INTERNATIONAL                    01160       FERNEY VOLTAIRE
# 4           COLLEGE LES COTES                    01289              PERONNAS
#
#               secteur    ips type_etablissement
# 0              public  110.4            COLLEGE
# 1              public  111.4            COLLEGE
# 2  privé sous contrat  111.3            COLLEGE
# 3              public  122.6            COLLEGE
# 4              public  102.2            COLLEGE

# %%
# merging
for session in df_raw_dnb_par_etablissement['session'].unique():
    # df_master = df_master.join(dfs_dnb_par_etablissement[session].set_index('uai'), on='uai', how='left', rsuffix=session)
    # print(session)
    df_master = pd.merge(df_master,dfs_dnb_par_etablissement[session][['uai', f'dnb_nombre_d_inscrits_{session}']], on='uai', how='left')
    df_master = pd.merge(df_master,dfs_dnb_par_etablissement[session][['uai', f'dnb_nombre_de_presents_{session}']], on='uai', how='left')
    df_master = pd.merge(df_master,dfs_dnb_par_etablissement[session][['uai', f'dnb_taux_de_reussite_{session}']], on='uai', how='left')
    df_master = pd.merge(df_master,dfs_dnb_par_etablissement[session][['uai', f'dnb_taux_de_sans_mention_{session}']], on='uai', how='left')
    df_master = pd.merge(df_master,dfs_dnb_par_etablissement[session][['uai', f'dnb_taux_de_mention_ab_{session}']], on='uai', how='left')
    df_master = pd.merge(df_master,dfs_dnb_par_etablissement[session][['uai', f'dnb_taux_de_mention_b_{session}']], on='uai', how='left')
    df_master = pd.merge(df_master,dfs_dnb_par_etablissement[session][['uai', f'dnb_taux_de_mention_tb_{session}']], on='uai', how='left')
    
    
df_master.head()
# Out:
#   rentree_scolaire academie code_du_departement departement       uai  \
# 0        2021-2022     LYON                 001         AIN  0010025X
# 1        2021-2022     LYON                 001         AIN  0010041P
# 2        2021-2022     LYON                 001         AIN  0010092V
# 3        2021-2022     LYON                 001         AIN  0010896U
# 4        2021-2022     LYON                 001         AIN  0010938P
#
#         nom_de_l_etablissment code_insee_de_la_commune     nom_de_la_commune  \
# 0      COLLEGE PAUL SIXDENIER                    01185  PLATEAU D HAUTEVILLE
# 1            COLLEGE VAUGELAS                    01244             MEXIMIEUX
# 2  COLLEGE PRIVE SAINT JOSEPH                    01283               OYONNAX
# 3       COLLEGE INTERNATIONAL                    01160       FERNEY VOLTAIRE
# 4           COLLEGE LES COTES                    01289              PERONNAS
#
#               secteur    ips  ... dnb_taux_de_mention_b_2016  \
# 0              public  110.4  ...                   0.119403
# 1              public  111.4  ...                   0.209402
# 2  privé sous contrat  111.3  ...                   0.211111
# 3              public  122.6  ...                   0.247619
# 4              public  102.2  ...                   0.203008
#
#    dnb_taux_de_mention_tb_2016  dnb_nombre_d_inscrits_2021  \
# 0                     0.059701                        61.0
# 1                     0.145299                       236.0
# 2                     0.133333                       120.0
# 3                     0.271429                       242.0
# 4                     0.157895                       141.0
#
#    dnb_nombre_de_presents_2021  dnb_nombre_de_presents_2021  \
# 0                         61.0                         58.0
# 1                        233.0                        207.0
# 2                        120.0                        111.0
# 3                        235.0                        214.0
# 4                        141.0                        131.0
#
#    dnb_taux_de_reussite_2021  dnb_taux_de_sans_mention_2021  \
# 0                       95.1                       0.114754
# 1                       88.8                       0.111588
# 2                       92.5                       0.166667
# 3                       91.1                       0.119149
# 4                       92.9                       0.156028
#
#    dnb_taux_de_mention_ab_2021  dnb_taux_de_mention_b_2021  \
# 0                     0.327869                    0.196721
# 1                     0.236052                    0.227468
# 2                     0.233333                    0.300000
# 3                     0.187234                    0.268085
# 4                     0.290780                    0.255319
#
#    dnb_taux_de_mention_tb_2021
# 0                     0.311475
# 1                     0.313305
# 2                     0.225000
# 3                     0.336170
# 4                     0.226950
#
# [5 rows x 139 columns]

# %%
df_master.rename(columns = {'code_du_departement':'code_departement', 
                            'nom_de_l_etablissment':'nom_etablissment',
                            'code_insee_de_la_commune':'code_insee_commune',
                            'nom_de_la_commune':'commune',
                            }, inplace = True)

# %%
# Moving columns
uai = df_master.pop('uai')
df_master.insert(0, 'uai', uai)
del uai

nom_etablissment = df_master.pop('nom_etablissment')
df_master.insert(1, 'nom_etablissment', nom_etablissment)
del nom_etablissment

type = df_master.pop('type_etablissement')
df_master.insert(3, 'type_etablissement', type)
del type

rentree_scolaire = df_master.pop('rentree_scolaire')
df_master.insert(11, 'rentree_scolaire', rentree_scolaire)
del rentree_scolaire

df_master.sample(5)
# Out:
# C:\Users\33671\AppData\Local\Temp\ipykernel_18128\3025118716.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_master.insert(0, 'uai', uai)
# C:\Users\33671\AppData\Local\Temp\ipykernel_18128\3025118716.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_master.insert(1, 'nom_etablissment', nom_etablissment)
# C:\Users\33671\AppData\Local\Temp\ipykernel_18128\3025118716.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_master.insert(3, 'type_etablissement', type)
# C:\Users\33671\AppData\Local\Temp\ipykernel_18128\3025118716.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_master.insert(11, 'rentree_scolaire', rentree_scolaire)
#             uai                nom_etablissment type_etablissement  academie  \
# 8247   0790684P                  ECOLE PRIMAIRE              ECOLE  POITIERS
# 13025  0932568L  ECOLE ELEMENTAIRE ANGELA DAVIS              ECOLE   CRETEIL
# 32899  0070126Z    ECOLE PRIMAIRE SAINT EXUPERY              ECOLE  GRENOBLE
# 37603  0770560R    ECOLE ELEMENTAIRE EMILE ZOLA              ECOLE   CRETEIL
# 32974  0080629R   GROUPE SCOLAIRE ABEL DECOPONS              ECOLE     REIMS
#
#       code_departement        departement code_insee_commune  \
# 8247               079        DEUX-SEVRES              79029
# 13025              093  SEINE-SAINT-DENIS              93027
# 32899              007            ARDECHE              07292
# 37603              077     SEINE-ET-MARNE              77513
# 32974              008           ARDENNES              08081
#
#                        commune secteur    ips  ...  \
# 8247   BEAULIEU SOUS PARTHENAY  public  109.1  ...
# 13025             LA COURNEUVE  public   80.4  ...
# 32899        SAINT ROMAIN D AY  public  101.2  ...
# 37603                 VILLENOY  public  103.2  ...
# 32974          BOGNY SUR MEUSE  public   84.0  ...
#
#        dnb_taux_de_mention_b_2016 dnb_taux_de_mention_tb_2016  \
# 8247                          NaN                         NaN
# 13025                         NaN                         NaN
# 32899                         NaN                         NaN
# 37603                         NaN                         NaN
# 32974                         NaN                         NaN
#
#        dnb_nombre_d_inscrits_2021  dnb_nombre_de_presents_2021  \
# 8247                          NaN                          NaN
# 13025                         NaN                          NaN
# 32899                         NaN                          NaN
# 37603                         NaN                          NaN
# 32974                         NaN                          NaN
#
#        dnb_nombre_de_presents_2021  dnb_taux_de_reussite_2021  \
# 8247                           NaN                        NaN
# 13025                          NaN                        NaN
# 32899                          NaN                        NaN
# 37603                          NaN                        NaN
# 32974                          NaN                        NaN
#
#        dnb_taux_de_sans_mention_2021  dnb_taux_de_mention_ab_2021  \
# 8247                             NaN                          NaN
# 13025                            NaN                          NaN
# 32899                            NaN                          NaN
# 37603                            NaN                          NaN
# 32974                            NaN                          NaN
#
#        dnb_taux_de_mention_b_2021  dnb_taux_de_mention_tb_2021
# 8247                          NaN                          NaN
# 13025                         NaN                          NaN
# 32899                         NaN                          NaN
# 37603                         NaN                          NaN
# 32974                         NaN                          NaN
#
# [5 rows x 139 columns]

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39058 entries, 0 to 39057
# Columns: 139 entries, uai to dnb_taux_de_mention_tb_2021
# dtypes: float64(129), object(10)
# memory usage: 41.7+ MB

# %% [markdown]
# ##### Merging geolocalisation dataset

# %%
df_raw_geolocalisation = df_raw_geolocalisation.rename(columns={'numero_uai': 'uai'})

# %%
df_master = df_master.join(df_raw_geolocalisation.set_index('uai'), on='uai', how='left', rsuffix='right')
df_master.sample(5)
# Out:
#             uai            nom_etablissment type_etablissement  \
# 13585  0030647M           ECOLE ELEMENTAIRE              ECOLE
# 61     0061459D       COLLEGE PRIVE FENELON            COLLEGE
# 30767  0130414E      ECOLE PRIMAIRE LA CRAU              ECOLE
# 38363  0890610E  ECOLE ELEMENTAIRE MUSCADET              ECOLE
# 30049  0622833T              ECOLE PRIMAIRE              ECOLE
#
#                academie code_departement       departement code_insee_commune  \
# 13585  CLERMONT-FERRAND              003            ALLIER              03108
# 61                 NICE              006   ALPES-MARITIMES              06069
# 30767     AIX-MARSEILLE              013  BOUCHES-DU-RHONE              13027
# 38363             DIJON              089             YONNE              89206
# 30049             LILLE              062     PAS-DE-CALAIS              62569
#
#                   commune             secteur    ips  ...  code_commune  \
# 13585         ECHASSIERES              public   93.3  ...         03108
# 61                 GRASSE  privé sous contrat  137.2  ...         06069
# 30767       CHATEAURENARD              public  107.3  ...         13027
# 38363              JOIGNY              public  107.7  ...         89206
# 30049  MERCK SAINT LIEVIN              public  100.8  ...         62569
#
#       libelle_departement              libelle_region  libelle_academie  \
# 13585              Allier        Auvergne-Rhône-Alpes  Clermont-Ferrand
# 61        Alpes-Maritimes  Provence-Alpes-Côte d'Azur              Nice
# 30767    Bouches-du-Rhône  Provence-Alpes-Côte d'Azur     Aix-Marseille
# 38363               Yonne     Bourgogne-Franche-Comté             Dijon
# 30049       Pas-de-Calais             Hauts-de-France             Lille
#
#                                                 position  \
# 13585  {'lon': 2.934629434199442, 'lat': 46.182957446...
# 61     {'lon': 6.92750389959421, 'lat': 43.6551547224...
# 30767  {'lon': 4.835840589495739, 'lat': 43.868618978...
# 38363  {'lon': 3.417429706169467, 'lat': 47.983642250...
# 30049  {'lon': 2.113870693773724, 'lat': 50.627465965...
#
#        secteur_prive_code_type_contrat    secteur_prive_libelle_type_contrat  \
# 13585                             99.0                            SANS OBJET
# 61                                30.0  CONTRAT D'ASSOCIATION TOUTES CLASSES
# 30767                             99.0                            SANS OBJET
# 38363                             99.0                            SANS OBJET
# 30049                             99.0                            SANS OBJET
#
#        code_ministere                   libelle_ministere  date_ouverture
# 13585             6.0  MINISTERE DE L'EDUCATION NATIONALE      1967-05-08
# 61                6.0  MINISTERE DE L'EDUCATION NATIONALE      1980-09-01
# 30767             6.0  MINISTERE DE L'EDUCATION NATIONALE      1965-07-10
# 38363             6.0  MINISTERE DE L'EDUCATION NATIONALE      1966-09-30
# 30049             6.0  MINISTERE DE L'EDUCATION NATIONALE      1972-09-01
#
# [5 rows x 173 columns]

# %%
# Removing joined columns not bringing any or enough value
df_master.drop(columns=['appellation_officielle', 'denomination_principale', 'patronyme_uai', 'secteur_public_prive_libe', 'adresse_uai',
                     'boite_postale_uai', 'localite_acheminement_uai', 'libelle_commune', 'localisation', 'nature_uai_libe',
                     'etat_etablissement', 'etat_etablissement_libe', 'code_departementright', 'code_commune', 'libelle_departement', 'libelle_academie', 
                     'secteur_prive_code_type_contrat', 'secteur_prive_libelle_type_contrat', 'code_ministere', 'libelle_ministere', 'nature_uai', 'lieu_dit_uai'], 
        errors='ignore', 
        inplace=True)

# %%
# Moving columns
code_academie = df_master.pop('code_academie')
df_master.insert(3, 'code_academie', code_academie)
del code_academie

code_region = df_master.pop('code_region')
df_master.insert(8, 'code_region', code_region)
del code_region

libelle_region = df_master.pop('libelle_region')
df_master.insert(9, 'libelle_region', libelle_region)
del libelle_region

df_master.sample(5)
# Out:
#             uai                             nom_etablissment  \
# 5007   0650835E                          COLLEGE VICTOR HUGO
# 14994  0301260G            ECOLE ELEMENTAIRE ROBERT LAVESQUE
# 872    0672304R                   COLLEGE PRIVE ECOLE AQUIBA
# 10511  0291990F  ECOLE PRIMAIRE PRIVEE NOTRE DAME DE LOURDES
# 37428  0760443U             ECOLE ELEMENTAIRE FRANCOIS CODET
#
#       type_etablissement  code_academie     academie code_departement  \
# 5007             COLLEGE           16.0     TOULOUSE              065
# 14994              ECOLE           11.0  MONTPELLIER              030
# 872              COLLEGE           15.0   STRASBOURG              067
# 10511              ECOLE           14.0       RENNES              029
# 37428              ECOLE           70.0    NORMANDIE              076
#
#            departement code_insee_commune  code_region libelle_region  ...  \
# 5007   HAUTES-PYRENEES              65440         76.0      Occitanie  ...
# 14994             GARD              30269         76.0      Occitanie  ...
# 872           BAS-RHIN              67482         44.0      Grand Est  ...
# 10511        FINISTERE              29151         53.0       Bretagne  ...
# 37428   SEINE MARITIME              76108         28.0      Normandie  ...
#
#       dnb_taux_de_mention_tb_2021 code_postal_uai  coordonnee_x  coordonnee_y  \
# 5007                     0.336134         65000.0      461604.8     6239965.7
# 14994                         NaN         30270.0      771264.5     6334861.7
# 872                      0.414634         67000.0     1050338.2     6842716.2
# 10511                         NaN         29600.0      196239.1     6852259.6
# 37428                         NaN         76230.0      563656.6     6931828.0
#
#             epsg   latitude  longitude  appariement  \
# 5007   EPSG:2154  43.219050    0.06723     Parfaite
# 14994  EPSG:2154  44.109144    3.89024     Parfaite
# 872    EPSG:2154  48.589724    7.75325     Parfaite
# 10511  EPSG:2154  48.574141   -3.83721     Parfaite
# 37428  EPSG:2154  49.471230    1.11943     Parfaite
#
#                                                 position  date_ouverture
# 5007   {'lon': 0.067229784054182, 'lat': 43.219049733...      1977-03-09
# 14994  {'lon': 3.890239611621374, 'lat': 44.109143753...      1974-05-15
# 872    {'lon': 7.7532499241539306, 'lat': 48.58972419...      1966-09-01
# 10511  {'lon': -3.837210373954562, 'lat': 48.57414098...      1984-07-04
# 37428  {'lon': 1.1194301513227891, 'lat': 49.47122982...      1966-11-24
#
# [5 rows x 151 columns]

# %%
df_master = df_master.rename(columns={'libelle_region': 'region'})

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39058 entries, 0 to 39057
# Columns: 151 entries, uai to date_ouverture
# dtypes: float64(136), object(15)
# memory usage: 45.3+ MB

# %% [markdown]
# ##### Merging Niveau_de_vie_2013_a_la_commune dataset

# %%
df_raw_revenus_par_commune = df_raw_revenus_par_commune.rename(columns={'Code Commune': 'code_insee_commune'})

# %%
df_master = df_master.join(df_raw_revenus_par_commune.set_index('code_insee_commune'), on='code_insee_commune', how='left', rsuffix='right')

# %%
# Removing joined columns not bringing any or enough value
df_master.drop(columns=['Nom Commune'], 
        errors='ignore', 
        inplace=True)

# %%
# Renaming columns
df_master.rename(columns = {'Niveau de vie Commune':'niveau_de_vie_commune', 
                            'Niveau de vie Département':'niveau_de_vie_departement'
                            }, inplace = True)

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39058 entries, 0 to 39057
# Columns: 153 entries, uai to niveau_de_vie_departement
# dtypes: float64(138), object(15)
# memory usage: 45.9+ MB

# %% [markdown]
# ##### Merging georef-france-commune dataset

# %% [markdown]
# ##### typo_rur

# %%
df_raw_typo_rur = df_raw_typo_rur.rename(columns={'codgeo': 'code_insee_commune'})

# %%
df_master = df_master.join(df_raw_typo_rur.set_index('code_insee_commune'), on='code_insee_commune', how='left', rsuffix='right')

# %%
df_master
# Out:
#             uai                              nom_etablissment  \
# 0      0010025X                        COLLEGE PAUL SIXDENIER
# 1      0010041P                              COLLEGE VAUGELAS
# 2      0010092V                    COLLEGE PRIVE SAINT JOSEPH
# 3      0010896U                         COLLEGE INTERNATIONAL
# 4      0010938P                             COLLEGE LES COTES
# ...         ...                                           ...
# 39053  9760209Y                ECOLE ELEMENTAIRE DE CHICONI 5
# 39054  9760253W  ECOLE ELEMENTAIRE PUBLIQUE MAJICAVO KOROPA 3
# 39055  9760301Y           ECOLE PRIMAIRE PUBLIQUE TSOUNDZOU 2
# 39056  9760302Z                ECOLE PRIMAIRE PUBLIQUE MROALE
# 39057  9760303A             ECOLE ELEMENTAIRE PUBLIQUE KAHANI
#
#       type_etablissement  code_academie academie code_departement departement  \
# 0                COLLEGE           10.0     LYON              001         AIN
# 1                COLLEGE           10.0     LYON              001         AIN
# 2                COLLEGE           10.0     LYON              001         AIN
# 3                COLLEGE           10.0     LYON              001         AIN
# 4                COLLEGE           10.0     LYON              001         AIN
# ...                  ...            ...      ...              ...         ...
# 39053              ECOLE           43.0  MAYOTTE              976     MAYOTTE
# 39054              ECOLE           43.0  MAYOTTE              976     MAYOTTE
# 39055              ECOLE           43.0  MAYOTTE              976     MAYOTTE
# 39056              ECOLE           43.0  MAYOTTE              976     MAYOTTE
# 39057              ECOLE           43.0  MAYOTTE              976     MAYOTTE
#
#       code_insee_commune  code_region                region  ...   latitude  \
# 0                  01185         84.0  Auvergne-Rhône-Alpes  ...  45.976219
# 1                  01244         84.0  Auvergne-Rhône-Alpes  ...  45.907542
# 2                  01283         84.0  Auvergne-Rhône-Alpes  ...  46.259653
# 3                  01160         84.0  Auvergne-Rhône-Alpes  ...  46.264811
# 4                  01289         84.0  Auvergne-Rhône-Alpes  ...  46.190009
# ...                  ...          ...                   ...  ...        ...
# 39053              97605          6.0               Mayotte  ... -12.836574
# 39054              97610          6.0               Mayotte  ... -12.744716
# 39055              97611          6.0               Mayotte  ... -12.817093
# 39056              97617          6.0               Mayotte  ... -12.788367
# 39057              97614          6.0               Mayotte  ... -12.823189
#
#        longitude  appariement  \
# 0       5.600967     Correcte
# 1       5.188640     Parfaite
# 2       5.656330     Parfaite
# 3       6.116650     Parfaite
# 4       5.205570     Parfaite
# ...          ...          ...
# 39053  45.115200     Parfaite
# 39054  45.218850     Parfaite
# 39055  45.197320     Parfaite
# 39056  45.128749     Correcte
# 39057  45.130200     Correcte
#
#                                                 position date_ouverture  \
# 0      {'lon': 5.600967267017193, 'lat': 45.976219204...     1965-05-01
# 1      {'lon': 5.188640403667234, 'lat': 45.907541813...     1971-02-16
# 2      {'lon': 5.65632989664765, 'lat': 46.2596533673...     1967-01-19
# 3      {'lon': 6.116650067099341, 'lat': 46.264811148...     1970-02-20
# 4      {'lon': 5.205570413701443, 'lat': 46.190008673...     1972-01-25
# ...                                                  ...            ...
# 39053  {'lon': 45.11520022047355, 'lat': -12.83657434...     1998-09-01
# 39054  {'lon': 45.218850302397314, 'lat': -12.7447159...     2001-09-01
# 39055  {'lon': 45.19731954390122, 'lat': -12.81709257...     2005-09-01
# 39056  {'lon': 45.12874934018609, 'lat': -12.78836708...     2005-09-01
# 39057  {'lon': 45.130199958022374, 'lat': -12.8231894...     2005-09-01
#
#        niveau_de_vie_commune  niveau_de_vie_departement                libgeo  \
# 0               20198.148148               22343.574665  Plateau d'Hauteville
# 1               21367.619048               22343.574665             Meximieux
# 2               16590.000000               22343.574665               Oyonnax
# 3               25508.333333               22343.574665       Ferney-Voltaire
# 4               21632.000000               22343.574665              Péronnas
# ...                      ...                        ...                   ...
# 39053                    NaN                        NaN               Chiconi
# 39054                    NaN                        NaN               Koungou
# 39055                    NaN                        NaN             Mamoudzou
# 39056                    NaN                        NaN              Tsingoni
# 39057                    NaN                        NaN              Ouangani
#
#        zonage_rur                zonage_rur_lib
# 0             2.0      rural autonome peu dense
# 1             5.0  urbain densité intermédiaire
# 2             5.0  urbain densité intermédiaire
# 3             5.0  urbain densité intermédiaire
# 4             5.0  urbain densité intermédiaire
# ...           ...                           ...
# 39053         5.0  urbain densité intermédiaire
# 39054         5.0  urbain densité intermédiaire
# 39055         6.0                  urbain dense
# 39056         5.0  urbain densité intermédiaire
# 39057         5.0  urbain densité intermédiaire
#
# [39058 rows x 156 columns]

# %%
df_master['zonage_rur_lib'].isnull().value_counts()
# Out:
# False    37860
# True      1198
# Name: zonage_rur_lib, dtype: int64

# %% [markdown]
# ### 6. Tidying up dataframe

# %%
# Making all strings lower case
df_master = df_master.applymap(lambda x: x.lower() if type(x) == str else x)

# renaming "privé sous contrat" in "prive"
df_master.loc[df_master["secteur"] == "privé sous contrat", "secteur"] = "prive"

# sorting
df_master.sort_values(by=['secteur', 'type_etablissement'], ascending=False, inplace=True)

# %%
df_master.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39058 entries, 6967 to 6962
# Data columns (total 156 columns):
#  #    Column                         Non-Null Count  Dtype
# ---   ------                         --------------  -----
#  0    uai                            39058 non-null  object
#  1    nom_etablissment               39058 non-null  object
#  2    type_etablissement             39058 non-null  object
#  3    code_academie                  38932 non-null  float64
#  4    academie                       39058 non-null  object
#  5    code_departement               39058 non-null  object
#  6    departement                    39058 non-null  object
#  7    code_insee_commune             39058 non-null  object
#  8    code_region                    38932 non-null  float64
#  9    region                         38932 non-null  object
#  10   commune                        39058 non-null  object
#  11   secteur                        39058 non-null  object
#  12   ips                            39053 non-null  float64
#  13   dnb_nombre_d_inscrits_2007     6671 non-null   float64
#  14   rentree_scolaire               39058 non-null  object
#  15   dnb_nombre_de_presents_2007    6671 non-null   float64
#  16   dnb_nombre_de_presents_2007    6671 non-null   float64
#  17   dnb_taux_de_reussite_2007      6671 non-null   float64
#  18   dnb_taux_de_sans_mention_2007  6671 non-null   float64
#  19   dnb_taux_de_mention_ab_2007    6671 non-null   float64
#  20   dnb_taux_de_mention_b_2007     6671 non-null   float64
#  21   dnb_taux_de_mention_tb_2007    6671 non-null   float64
#  22   dnb_nombre_d_inscrits_2008     6696 non-null   float64
#  23   dnb_nombre_de_presents_2008    6696 non-null   float64
#  24   dnb_nombre_de_presents_2008    6696 non-null   float64
#  25   dnb_taux_de_reussite_2008      6696 non-null   float64
#  26   dnb_taux_de_sans_mention_2008  6696 non-null   float64
#  27   dnb_taux_de_mention_ab_2008    6696 non-null   float64
#  28   dnb_taux_de_mention_b_2008     6696 non-null   float64
#  29   dnb_taux_de_mention_tb_2008    6696 non-null   float64
#  30   dnb_nombre_d_inscrits_2011     6775 non-null   float64
#  31   dnb_nombre_de_presents_2011    6775 non-null   float64
#  32   dnb_nombre_de_presents_2011    6775 non-null   float64
#  33   dnb_taux_de_reussite_2011      6775 non-null   float64
#  34   dnb_taux_de_sans_mention_2011  6775 non-null   float64
#  35   dnb_taux_de_mention_ab_2011    6775 non-null   float64
#  36   dnb_taux_de_mention_b_2011     6775 non-null   float64
#  37   dnb_taux_de_mention_tb_2011    6775 non-null   float64
#  38   dnb_nombre_d_inscrits_2012     6793 non-null   float64
#  39   dnb_nombre_de_presents_2012    6793 non-null   float64
#  40   dnb_nombre_de_presents_2012    6793 non-null   float64
#  41   dnb_taux_de_reussite_2012      6793 non-null   float64
#  42   dnb_taux_de_sans_mention_2012  6793 non-null   float64
#  43   dnb_taux_de_mention_ab_2012    6793 non-null   float64
#  44   dnb_taux_de_mention_b_2012     6793 non-null   float64
#  45   dnb_taux_de_mention_tb_2012    6793 non-null   float64
#  46   dnb_nombre_d_inscrits_2006     6650 non-null   float64
#  47   dnb_nombre_de_presents_2006    6650 non-null   float64
#  48   dnb_nombre_de_presents_2006    6650 non-null   float64
#  49   dnb_taux_de_reussite_2006      6650 non-null   float64
#  50   dnb_taux_de_sans_mention_2006  6650 non-null   float64
#  51   dnb_taux_de_mention_ab_2006    6650 non-null   float64
#  52   dnb_taux_de_mention_b_2006     6650 non-null   float64
#  53   dnb_taux_de_mention_tb_2006    6650 non-null   float64
#  54   dnb_nombre_d_inscrits_2009     6718 non-null   float64
#  55   dnb_nombre_de_presents_2009    6718 non-null   float64
#  56   dnb_nombre_de_presents_2009    6718 non-null   float64
#  57   dnb_taux_de_reussite_2009      6718 non-null   float64
#  58   dnb_taux_de_sans_mention_2009  6718 non-null   float64
#  59   dnb_taux_de_mention_ab_2009    6718 non-null   float64
#  60   dnb_taux_de_mention_b_2009     6718 non-null   float64
#  61   dnb_taux_de_mention_tb_2009    6718 non-null   float64
#  62   dnb_nombre_d_inscrits_2010     6736 non-null   float64
#  63   dnb_nombre_de_presents_2010    6736 non-null   float64
#  64   dnb_nombre_de_presents_2010    6736 non-null   float64
#  65   dnb_taux_de_reussite_2010      6736 non-null   float64
#  66   dnb_taux_de_sans_mention_2010  6736 non-null   float64
#  67   dnb_taux_de_mention_ab_2010    6736 non-null   float64
#  68   dnb_taux_de_mention_b_2010     6736 non-null   float64
#  69   dnb_taux_de_mention_tb_2010    6736 non-null   float64
#  70   dnb_nombre_d_inscrits_2013     6804 non-null   float64
#  71   dnb_nombre_de_presents_2013    6804 non-null   float64
#  72   dnb_nombre_de_presents_2013    6804 non-null   float64
#  73   dnb_taux_de_reussite_2013      6804 non-null   float64
#  74   dnb_taux_de_sans_mention_2013  6804 non-null   float64
#  75   dnb_taux_de_mention_ab_2013    6804 non-null   float64
#  76   dnb_taux_de_mention_b_2013     6804 non-null   float64
#  77   dnb_taux_de_mention_tb_2013    6804 non-null   float64
#  78   dnb_nombre_d_inscrits_2014     6815 non-null   float64
#  79   dnb_nombre_de_presents_2014    6815 non-null   float64
#  80   dnb_nombre_de_presents_2014    6815 non-null   float64
#  81   dnb_taux_de_reussite_2014      6815 non-null   float64
#  82   dnb_taux_de_sans_mention_2014  6815 non-null   float64
#  83   dnb_taux_de_mention_ab_2014    6815 non-null   float64
#  84   dnb_taux_de_mention_b_2014     6815 non-null   float64
#  85   dnb_taux_de_mention_tb_2014    6815 non-null   float64
#  86   dnb_nombre_d_inscrits_2019     6898 non-null   float64
#  87   dnb_nombre_de_presents_2019    6898 non-null   float64
#  88   dnb_nombre_de_presents_2019    6898 non-null   float64
#  89   dnb_taux_de_reussite_2019      6898 non-null   float64
#  90   dnb_taux_de_sans_mention_2019  6898 non-null   float64
#  91   dnb_taux_de_mention_ab_2019    6898 non-null   float64
#  92   dnb_taux_de_mention_b_2019     6898 non-null   float64
#  93   dnb_taux_de_mention_tb_2019    6898 non-null   float64
#  94   dnb_nombre_d_inscrits_2020     6907 non-null   float64
#  95   dnb_nombre_de_presents_2020    6907 non-null   float64
#  96   dnb_nombre_de_presents_2020    6907 non-null   float64
#  97   dnb_taux_de_reussite_2020      6907 non-null   float64
#  98   dnb_taux_de_sans_mention_2020  6907 non-null   float64
#  99   dnb_taux_de_mention_ab_2020    6907 non-null   float64
#  100  dnb_taux_de_mention_b_2020     6907 non-null   float64
#  101  dnb_taux_de_mention_tb_2020    6907 non-null   float64
#  102  dnb_nombre_d_inscrits_2015     6831 non-null   float64
#  103  dnb_nombre_de_presents_2015    6831 non-null   float64
#  104  dnb_nombre_de_presents_2015    6831 non-null   float64
#  105  dnb_taux_de_reussite_2015      6831 non-null   float64
#  106  dnb_taux_de_sans_mention_2015  6831 non-null   float64
#  107  dnb_taux_de_mention_ab_2015    6831 non-null   float64
#  108  dnb_taux_de_mention_b_2015     6831 non-null   float64
#  109  dnb_taux_de_mention_tb_2015    6831 non-null   float64
#  110  dnb_nombre_d_inscrits_2017     6863 non-null   float64
#  111  dnb_nombre_de_presents_2017    6863 non-null   float64
#  112  dnb_nombre_de_presents_2017    6863 non-null   float64
#  113  dnb_taux_de_reussite_2017      6863 non-null   float64
#  114  dnb_taux_de_sans_mention_2017  6863 non-null   float64
#  115  dnb_taux_de_mention_ab_2017    6863 non-null   float64
#  116  dnb_taux_de_mention_b_2017     6863 non-null   float64
#  117  dnb_taux_de_mention_tb_2017    6863 non-null   float64
#  118  dnb_nombre_d_inscrits_2018     6882 non-null   float64
#  119  dnb_nombre_de_presents_2018    6882 non-null   float64
#  120  dnb_nombre_de_presents_2018    6882 non-null   float64
#  121  dnb_taux_de_reussite_2018      6882 non-null   float64
#  122  dnb_taux_de_sans_mention_2018  6882 non-null   float64
#  123  dnb_taux_de_mention_ab_2018    6882 non-null   float64
#  124  dnb_taux_de_mention_b_2018     6882 non-null   float64
#  125  dnb_taux_de_mention_tb_2018    6882 non-null   float64
#  126  dnb_nombre_d_inscrits_2016     6849 non-null   float64
#  127  dnb_nombre_de_presents_2016    6849 non-null   float64
#  128  dnb_nombre_de_presents_2016    6849 non-null   float64
#  129  dnb_taux_de_reussite_2016      6849 non-null   float64
#  130  dnb_taux_de_sans_mention_2016  6849 non-null   float64
#  131  dnb_taux_de_mention_ab_2016    6849 non-null   float64
#  132  dnb_taux_de_mention_b_2016     6849 non-null   float64
#  133  dnb_taux_de_mention_tb_2016    6849 non-null   float64
#  134  dnb_nombre_d_inscrits_2021     6927 non-null   float64
#  135  dnb_nombre_de_presents_2021    6927 non-null   float64
#  136  dnb_nombre_de_presents_2021    6927 non-null   float64
#  137  dnb_taux_de_reussite_2021      6927 non-null   float64
#  138  dnb_taux_de_sans_mention_2021  6927 non-null   float64
#  139  dnb_taux_de_mention_ab_2021    6927 non-null   float64
#  140  dnb_taux_de_mention_b_2021     6927 non-null   float64
#  141  dnb_taux_de_mention_tb_2021    6927 non-null   float64
#  142  code_postal_uai                38932 non-null  float64
#  143  coordonnee_x                   38932 non-null  float64
#  144  coordonnee_y                   38932 non-null  float64
#  145  epsg                           38932 non-null  object
#  146  latitude                       38932 non-null  float64
#  147  longitude                      38932 non-null  float64
#  148  appariement                    38932 non-null  object
#  149  position                       38932 non-null  object
#  150  date_ouverture                 38932 non-null  object
#  151  niveau_de_vie_commune          37846 non-null  float64
#  152  niveau_de_vie_departement      37870 non-null  float64
#  153  libgeo                         37860 non-null  object
#  154  zonage_rur                     37860 non-null  float64
#  155  zonage_rur_lib                 37860 non-null  object
# dtypes: float64(139), object(17)
# memory usage: 46.8+ MB

# %% [markdown]
# ### 7. Exporting workfile data to CSV

# %%
file_name = "df_master" + ".csv"
print(f"file name: {file_name}")
df_master.to_csv(data_out + file_name, index = False)


# Code to comment at some point
timestr = time.strftime("%Y-%m-%d_%H-%M-%S")
file_name = "df_master_" + timestr + ".csv"
print(f"file name: {file_name}")
df_master.to_csv(data_out_temporary + file_name, index = False)
# Out:
# file name: df_master.csv
# file name: df_master_2022-11-12_13-13-35.csv

# %% [markdown]
# #### data-collection notebook execution time

# %%
executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# Execution time in seconds: 104.7528932094574
